# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import sys
from transformers import AutoTokenizer
import pandas as pd #🐼
import seaborn as sns
# %matplotlib inline

# %%
sys.path.insert(0, '../code')

# %%
import data_analysis_functions as da
import data_process
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/kyonkyon/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(300,)))
model.add(tf.keras.layers.Embedding(30523, 256))
model.add(tf.keras.layers.Conv1D(filters = 150, kernel_size=2))
model.add(tf.keras.layers.Dense(54, activation='tanh'))
model.add(tf.keras.layers.MaxPooling1D(pool_size=11))
model.add(tf.keras.layers.Conv1D(filters = 11, kernel_size=1))
model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(242, return_sequences=True), input_shape=(5, 10)))
model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(242))) 
model.add(tf.keras.layers.Dense(1, activation='tanh'))
model.compile(loss='mse',
             optimizer = tf.keras.optimizers.Adam(learning_rate=0.001))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 300, 256)          7813888
#
#  conv1d (Conv1D)             (None, 299, 150)          76950
#
#  dense (Dense)               (None, 299, 54)           8154
#
#  max_pooling1d (MaxPooling1D  (None, 27, 54)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 27, 11)            605
#
#  bidirectional (Bidirectiona  (None, 27, 484)          491744
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 484)              1407472
#  nal)
#
#  dense_1 (Dense)             (None, 1)                 485
#
# =================================================================
# Total params: 9,799,298
# Trainable params: 9,799,298
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_df = da.importData('../code/data/training_set.csv')
test_df = da.importData('../code/data/test_set.csv')
train_df = data_process.data_vectorization(train_df)
test_df = data_process.data_vectorization(test_df)

# %%
def filter_long_descriptions(tokenizer, descriptions, max_len):
    indices = []
    lengths = tokenizer(descriptions, padding=False,
                     truncation=False, return_length=True)['length']
    for i in range(len(descriptions)):
        if lengths[i] <= max_len - 2:
            indices.append(i)
    return indices

# %%
tokenizer = AutoTokenizer.from_pretrained("GroNLP/hateBERT")

# %%
def short_description(df):
    # print(df.cleaned_comment.tolist())
    short_descriptions = filter_long_descriptions(tokenizer, df.cleaned_comment.tolist(), 300)
    # print('short descriptions')
    # print(short_descriptions)
    data = np.array(df['encoded_comment'])[short_descriptions]
    # print(data)
    target = df['score']
    return data, target

# %%
train_data, train_target = short_description(train_df)
test_data, test_target = short_description(test_df)

# %%
for i in range(len(train_data)):
    train_data[i] = np.array(train_data[i]).astype(np.float32)
    train_data[i] = train_data[i].flatten()

# %%
model.fit(np.stack(train_data, 0), train_target, epochs = 7)
# score = self.model.predict(np.stack(test_data, 0)).flatten()
result = model.evaluate(np.stack(test_data, 0), test_target)
# Out:
# Epoch 1/7
# 144/144 [==============================] - 47s 288ms/step - loss: 0.0776
# Epoch 2/7
# 144/144 [==============================] - 44s 305ms/step - loss: 0.0283
# Epoch 3/7
# 144/144 [==============================] - 47s 325ms/step - loss: 0.0140
# Epoch 4/7
# 144/144 [==============================] - 47s 325ms/step - loss: 0.0087
# Epoch 5/7
# 144/144 [==============================] - 44s 305ms/step - loss: 0.0060
# Epoch 6/7
# 144/144 [==============================] - 66s 463ms/step - loss: 0.0049
# Epoch 7/7
# 144/144 [==============================] - 81s 561ms/step - loss: 0.0036
# 35/35 [==============================] - 10s 149ms/step - loss: 0.0397

# %%
result
# Out:
# 0.03974352404475212

# %%
score = model.predict(np.stack(test_data, 0)).flatten()

# %%
data = {'comment':test_df['comment'], 'score':test_target, 'model score':score}
result_df = pd.DataFrame(data=data)

# %%
result_df
# Out:
#                                                 comment  score  model score
# 0     I’d start by not clicking on things that make ...  0.312     0.329279
# 1     If you count killing civilians as a success (w...  0.104     0.166436
# 2                       Sure, if it's private, why not? -0.574    -0.389752
# 3     Dude, most of these people support VERY LATE a...  0.438     0.248100
# 4     So you'll be OK if Trump gets elected and bypa...  0.062    -0.234001
# 5     Dont worry, it did a pretty good job of censor... -0.354    -0.152882
# 6     Humans do inherit traits, but they do NOT inhe... -0.312    -0.082361
# 7     Been in politics 50 years Joe. So it’s just no...  0.213    -0.212620
# 8     That's a perfectly valid criticism to make.  B... -0.085    -0.035983
# 9     What should they do? Welcome Hamas with open a... -0.042     0.116149
# 10    They didn't say all within were, just that it ... -0.208     0.027547
# 11    Hurricane Florence killed 14 people, all vacci...  0.109     0.109587
# 12    The reason they probably ended up wanting to f...  0.500     0.560726
# 13    So media outlets should just suppress informat...  0.000     0.013198
# 14    I usually excuse myself to the bathroom and wa...  0.426     0.057895
# 15    He's terrified of Winnie the Pooh and keeps wa...  0.083    -0.230783
# 16    oof..thats still farway for me..also, anyway t...  0.109     0.084797
# 17    If religious institutions were taxed, you'd st...  0.042    -0.102038
# 18    Judge needs to be removed from the case. As a ...  0.146    -0.057446
# 19    I am going to assume that by private charter s... -0.354    -0.222340
# 20    Because you alienate an entire religion. Plus ... -0.021     0.207583
# 21    I had a former coworker who would constantly h...  0.562     0.417595
# 22    You can’t even find 3 people to testify equal ... -0.292    -0.155771
# 23    I'm just 14 hours late to make this comment. C... -0.500    -0.512366
# 24    The discrimination comes more from the lesbian... -0.021    -0.017793
# 25               Turned to stone?  Thought he blew up.  -0.021    -0.388345
# 26    Compassion isn't the GOP's thing. They like to... -0.125    -0.009119
# 27    Soulsborne series? (Dark Souls 1-3, Demon Soul... -0.458    -0.151607
# 28    It’s a generation thing. The older people (the...  0.064    -0.130949
# 29                              What's wrong with soy?  -0.625     0.240575
# ...                                                 ...    ...          ...
# 1086  A Schiit Modi 2/Magni 2 or ODAC/O2 will do the... -0.375    -0.091212
# 1087  Because what happens in one part of the world ... -0.167    -0.087395
# 1088  It would be flooded with Simplified Chinese sc... -0.021    -0.148959
# 1089                          This is so sexy! Love it! -0.562    -0.480287
# 1090  Not sure why Im being down voted? Why does the... -0.191    -0.199008
# 1091  I am millionaire now. If this is true, I will ... -0.438    -0.393220
# 1092  It's a little difficult to explain but I'm not... -0.188    -0.287530
# 1093  I would also be careful about assuming that so... -0.125    -0.166961
# 1094          the space differences dont allow for this -0.542    -0.519311
# 1095  Probably not what you're looking for but Nick ... -0.250    -0.250883
# 1096                   And Putin is the Killer Rabbit.   0.062    -0.276825
# 1097  This entire concept of the Republican Party ha... -0.042     0.022319
# 1098  Guilty of doing this when I was younger. Feel ... -0.208    -0.487427
# 1099  Depends if taking that workload is due to the ...  0.062    -0.198305
# 1100  >How is this airline not painting a bright red...  0.271    -0.022734
# 1101                     Don’t poach dangerous animals  -0.326    -0.364942
# 1102  I am a cop that took paternal leave so that my... -0.319    -0.285482
# 1103  I remember a post complaining about him having...  0.854     0.702937
# 1104  Can dragonfly's create a house out of their bu...  0.085     0.047352
# 1105  7:50! Down from 9:22 in May! I just transition... -0.511    -0.464912
# 1106  I think cuck is one of the funniest words ever...  0.396     0.100870
# 1107  Fine with me. Done it. But I am one that can c...  0.188    -0.013133
# 1108  Can you give me an example of sexism against m...  0.250     0.582698
# 1109  This cemented it for me today. Listening to th...  0.104    -0.054498
# 1110  >  ultra-fascist Supreme Court\n\nGoddamn. Hyp...  0.250    -0.034324
# 1111  Well everyone's different. Like I said it's ju...  0.348     0.261790
# 1112  Completely agree. This is technically a "first... -0.489    -0.361505
# 1113           He said it was a hypothetical situation. -0.511    -0.310287
# 1114  But it's not right. You shouldn't have to give... -0.333    -0.261095
# 1115  After a year since I started the anime, I fina... -0.479    -0.156313
#
# [1116 rows x 3 columns]

# %%
confusion_matrix = [
    [0, 0, 0], 
    [0, 0, 0], 
    [0, 0, 0], 
]

# %%
count = 0
for index, row in result_df.iterrows():
    #non offensive
    if row['score'] <= -0.5:
        if row['model score'] <= -0.5:
            confusion_matrix[0][0] = confusion_matrix[0][0] + 1
        elif row['model score'] >= 0.5:
            confusion_matrix[0][2] = confusion_matrix[0][2] + 1
        else:
            confusion_matrix[0][1] = confusion_matrix[0][1] + 1
    #offensive 
    elif row['score'] >= 0.5:
        if row['model score'] <= -0.5:
            confusion_matrix[2][0] = confusion_matrix[2][0] + 1
        elif row['model score'] >= 0.5:
            confusion_matrix[2][2] = confusion_matrix[2][2] + 1
        else:
            confusion_matrix[2][1] = confusion_matrix[2][1] + 1     
    #neutral
    else:
        if row['model score'] <= -0.5:
            confusion_matrix[1][0] = confusion_matrix[1][0] + 1
        elif row['model score'] >= 0.5:
            confusion_matrix[1][2] = confusion_matrix[1][2] + 1
        else:
            confusion_matrix[1][1] = confusion_matrix[1][1] + 1

    dif = abs(row['score']) - abs(row['model score'])
    if abs(dif) < 0.2:
        count = count + 1 
print('Accuracy', count / len(result_df))
# Out:
# Accuracy 0.7840501792114696

# %%
confusion_matrix
# Out:
# [[21, 55, 0], [9, 919, 12], [0, 34, 66]]

# %%
labels = ['Non Offensive', 'Neutral', 'Offensive']

# %%
cf_df = pd.DataFrame(data=confusion_matrix, columns=labels, index=labels)

# %%
sns.heatmap(cf_df, annot=True, cmap="Blues_r")
# Out:
# <AxesSubplot:>
