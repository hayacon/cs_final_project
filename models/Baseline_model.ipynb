# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import sys
from transformers import AutoTokenizer
import pandas as pd #🐼
import seaborn as sns
# %matplotlib inline

# %%
sys.path.insert(0, '../code')

# %%
import data_analysis_functions as da
import data_process
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/kyonkyon/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(300,)))
model.add(tf.keras.layers.Embedding(30523, 256))
model.add(tf.keras.layers.Conv1D(filters = 150, kernel_size=2))
model.add(tf.keras.layers.MaxPooling1D(pool_size=2))
model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(10, return_sequences=True), input_shape=(5, 10)))
model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(10)))
model.add(tf.keras.layers.Dense(1, activation='tanh'))
model.compile(loss='mse',
             optimizer = tf.keras.optimizers.Adam(learning_rate=0.001))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 300, 256)          7813888
#
#  conv1d (Conv1D)             (None, 291, 300)          768300
#
#  max_pooling1d (MaxPooling1D  (None, 145, 300)         0
#  )
#
#  bidirectional (Bidirectiona  (None, 145, 20)          24880
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 20)               2480
#  nal)
#
#  dense (Dense)               (None, 1)                 21
#
# =================================================================
# Total params: 8,609,569
# Trainable params: 8,609,569
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_df = da.importData('../code/data/training_set.csv')
test_df = da.importData('../code/data/test_set.csv')
train_df = data_process.data_vectorization(train_df)
test_df = data_process.data_vectorization(test_df)

# %%
def filter_long_descriptions(tokenizer, descriptions, max_len):
    indices = []
    lengths = tokenizer(descriptions, padding=False,
                     truncation=False, return_length=True)['length']
    for i in range(len(descriptions)):
        if lengths[i] <= max_len - 2:
            indices.append(i)
    return indices

# %%
tokenizer = AutoTokenizer.from_pretrained("GroNLP/hateBERT")

# %%
def short_description(df):
    # print(df.cleaned_comment.tolist())
    short_descriptions = filter_long_descriptions(tokenizer, df.cleaned_comment.tolist(), 300)
    # print('short descriptions')
    # print(short_descriptions)
    data = np.array(df['encoded_comment'])[short_descriptions]
    # print(data)
    target = df['score']
    return data, target

# %%
train_data, train_target = short_description(train_df)
test_data, test_target = short_description(test_df)

# %%
for i in range(len(train_data)):
    train_data[i] = np.array(train_data[i]).astype(np.float32)
    train_data[i] = train_data[i].flatten()

# %%
model.fit(np.stack(train_data, 0), train_target, epochs = 7)
# score = self.model.predict(np.stack(test_data, 0)).flatten()
result = model.evaluate(np.stack(test_data, 0), test_target)
# Out:
# Epoch 1/7
# 144/144 [==============================] - 75s 485ms/step - loss: 0.0911
# Epoch 2/7
# 144/144 [==============================] - 67s 467ms/step - loss: 0.0298
# Epoch 3/7
# 144/144 [==============================] - 67s 464ms/step - loss: 0.0150
# Epoch 4/7
# 144/144 [==============================] - 68s 472ms/step - loss: 0.0078
# Epoch 5/7
# 144/144 [==============================] - 72s 501ms/step - loss: 0.0048
# Epoch 6/7
# 144/144 [==============================] - 72s 503ms/step - loss: 0.0034
# Epoch 7/7
# 144/144 [==============================] - 73s 509ms/step - loss: 0.0027
# 35/35 [==============================] - 6s 124ms/step - loss: 0.0418

# %%
result
# Out:
# 0.04182494431734085

# %%
score = model.predict(np.stack(test_data, 0)).flatten()

# %%
data = {'comment':test_df['comment'], 'score':test_target, 'model score':score}
result_df = pd.DataFrame(data=data)

# %%
result_df
# Out:
#                                                 comment  score  model score
# 0     I’d start by not clicking on things that make ...  0.312     0.288168
# 1     If you count killing civilians as a success (w...  0.104     0.083509
# 2                       Sure, if it's private, why not? -0.574    -0.434905
# 3     Dude, most of these people support VERY LATE a...  0.438     0.495215
# 4     So you'll be OK if Trump gets elected and bypa...  0.062    -0.000483
# 5     Dont worry, it did a pretty good job of censor... -0.354    -0.266441
# 6     Humans do inherit traits, but they do NOT inhe... -0.312    -0.054261
# 7     Been in politics 50 years Joe. So it’s just no...  0.213    -0.244308
# 8     That's a perfectly valid criticism to make.  B... -0.085     0.071573
# 9     What should they do? Welcome Hamas with open a... -0.042    -0.018972
# 10    They didn't say all within were, just that it ... -0.208     0.158359
# 11    Hurricane Florence killed 14 people, all vacci...  0.109    -0.093811
# 12    The reason they probably ended up wanting to f...  0.500     0.597352
# 13    So media outlets should just suppress informat...  0.000     0.066468
# 14    I usually excuse myself to the bathroom and wa...  0.426    -0.128316
# 15    He's terrified of Winnie the Pooh and keeps wa...  0.083    -0.097176
# 16    oof..thats still farway for me..also, anyway t...  0.109     0.246790
# 17    If religious institutions were taxed, you'd st...  0.042    -0.167213
# 18    Judge needs to be removed from the case. As a ...  0.146     0.086345
# 19    I am going to assume that by private charter s... -0.354    -0.263111
# 20    Because you alienate an entire religion. Plus ... -0.021     0.125021
# 21    I had a former coworker who would constantly h...  0.562     0.249253
# 22    You can’t even find 3 people to testify equal ... -0.292    -0.041550
# 23    I'm just 14 hours late to make this comment. C... -0.500    -0.390138
# 24    The discrimination comes more from the lesbian... -0.021     0.037090
# 25               Turned to stone?  Thought he blew up.  -0.021    -0.164148
# 26    Compassion isn't the GOP's thing. They like to... -0.125     0.034243
# 27    Soulsborne series? (Dark Souls 1-3, Demon Soul... -0.458    -0.128646
# 28    It’s a generation thing. The older people (the...  0.064    -0.153088
# 29                              What's wrong with soy?  -0.625    -0.264629
# ...                                                 ...    ...          ...
# 1086  A Schiit Modi 2/Magni 2 or ODAC/O2 will do the... -0.375    -0.075174
# 1087  Because what happens in one part of the world ... -0.167    -0.142369
# 1088  It would be flooded with Simplified Chinese sc... -0.021    -0.192681
# 1089                          This is so sexy! Love it! -0.562    -0.432574
# 1090  Not sure why Im being down voted? Why does the... -0.191    -0.147935
# 1091  I am millionaire now. If this is true, I will ... -0.438    -0.175021
# 1092  It's a little difficult to explain but I'm not... -0.188    -0.155568
# 1093  I would also be careful about assuming that so... -0.125     0.000221
# 1094          the space differences dont allow for this -0.542    -0.491259
# 1095  Probably not what you're looking for but Nick ... -0.250    -0.163047
# 1096                   And Putin is the Killer Rabbit.   0.062    -0.134513
# 1097  This entire concept of the Republican Party ha... -0.042     0.024233
# 1098  Guilty of doing this when I was younger. Feel ... -0.208    -0.458786
# 1099  Depends if taking that workload is due to the ...  0.062    -0.086106
# 1100  >How is this airline not painting a bright red...  0.271    -0.070588
# 1101                     Don’t poach dangerous animals  -0.326    -0.384128
# 1102  I am a cop that took paternal leave so that my... -0.319    -0.181178
# 1103  I remember a post complaining about him having...  0.854     0.679487
# 1104  Can dragonfly's create a house out of their bu...  0.085    -0.078816
# 1105  7:50! Down from 9:22 in May! I just transition... -0.511    -0.441752
# 1106  I think cuck is one of the funniest words ever...  0.396     0.086738
# 1107  Fine with me. Done it. But I am one that can c...  0.188     0.090845
# 1108  Can you give me an example of sexism against m...  0.250     0.333812
# 1109  This cemented it for me today. Listening to th...  0.104    -0.019145
# 1110  >  ultra-fascist Supreme Court\n\nGoddamn. Hyp...  0.250     0.017692
# 1111  Well everyone's different. Like I said it's ju...  0.348     0.089078
# 1112  Completely agree. This is technically a "first... -0.489    -0.452221
# 1113           He said it was a hypothetical situation. -0.511    -0.300314
# 1114  But it's not right. You shouldn't have to give... -0.333    -0.358263
# 1115  After a year since I started the anime, I fina... -0.479    -0.165314
#
# [1116 rows x 3 columns]

# %%
confusion_matrix = [
    [0, 0, 0], 
    [0, 0, 0], 
    [0, 0, 0], 
]

# %%
count1 = 0
count2 = 0
for index, row in result_df.iterrows():
    #non offensive
    if row['score'] <= -0.4:
        if row['model score'] <= -0.4:
            confusion_matrix[0][0] = confusion_matrix[0][0] + 1
        elif row['model score'] >= 0.4:
            confusion_matrix[0][2] = confusion_matrix[0][2] + 1
        else:
            confusion_matrix[0][1] = confusion_matrix[0][1] + 1
    #offensive 
    elif row['score'] >= 0.4:
        if row['model score'] <= -0.4:
            confusion_matrix[2][0] = confusion_matrix[2][0] + 1
        elif row['model score'] >= 0.4:
            confusion_matrix[2][2] = confusion_matrix[2][2] + 1
        else:
            confusion_matrix[2][1] = confusion_matrix[2][1] + 1     
    #neutral
    else:
        if row['model score'] <= -0.4:
            confusion_matrix[1][0] = confusion_matrix[1][0] + 1
        elif row['model score'] >= 0.4:
            confusion_matrix[1][2] = confusion_matrix[1][2] + 1
        else:
            confusion_matrix[1][1] = confusion_matrix[1][1] + 1

    dif = abs(row['score']) - abs(row['model score'])
    if abs(dif) < 0.2:
        count1 = count1 + 1 
    if abs(dif) < 0.1:
        count2 = count2 + 1
accuracy1 = count1 / len(result_df)
accuracy2 = count2 / len(result_df)

# %%
confusion_matrix
# Out:
# [[129, 314, 0], [79, 5552, 45], [0, 279, 298]]

# %%
labels = ['Non Offensive', 'Neutral', 'Offensive']

# %%
cf_df = pd.DataFrame(data=confusion_matrix, columns=labels, index=labels)

# %%
sns.heatmap(cf_df, annot=True, cmap="Blues_r")
# Out:
# <AxesSubplot:>

# %%
print('MSE : ', result)
# Out:
# MSE :  0.04182494431734085

# %%
print('Accuracy (>0.2): ', accuracy1)
print('Accuracy (>0.1): ', accuracy2)
# Out:
# Accuracy (>0.2):  0.7652329749103942
# Accuracy (>0.1):  0.4946236559139785
